# %%
import matplotlib.pyplot as plt

# Main path coordinates
global_path = [
    (48.44504165649414, -125.49838256835938),
    (48.428688049316406, -125.89652252197266),
    (48.41095733642578, -126.29439544677734),
    (48.391849517822266, -126.69197845458984),
    (48.37137222290039, -127.0892562866211),
    (48.34952163696289, -127.4862060546875),
    (48.32630157470703, -127.88280487060547),
    (48.30171585083008, -128.27903747558594),
    (48.2757682800293, -128.67486572265625),
    (48.24845886230469, -129.07029724121094),
    (48.219791412353516, -129.4652862548828),
    (48.18976593017578, -129.85983276367188),
    (48.158390045166016, -130.25390625),
    (48.16725158691406, -130.6519317626953),
    (48.17473602294922, -131.05007934570312),
    (48.18083953857422, -131.44833374023438),
    (48.18556594848633, -131.84666442871094),
    (48.188907623291016, -132.2450714111328),
    (48.19086837768555, -132.6435089111328),
    (48.19145202636719, -133.04196166992188),
    (48.190650939941406, -133.4404296875),
    (48.188472747802734, -133.8388671875),
    (48.18490982055664, -134.2372589111328),
    (48.179969787597656, -134.6355743408203),
    (48.173648834228516, -135.0338134765625),
    (48.16594696044922, -135.43194580078125),
    (48.15686798095703, -135.82994079589844),
    (48.14641189575195, -136.22779846191406),
    (48.13457489013672, -136.62547302246094),
    (48.121368408203125, -137.02294921875),
]

# Extra points
local_path = [
    (48.46022415161133, -125.0999984741211),
    (48.516258239746094, -126.83209228515625),
    (48.502681732177734, -129.04656982421875),
    (48.38160705566406, -131.05075073242188),
    (48.536441802978516, -133.281982421875),
    (48.33808517456055, -135.47926330566406),
    (48.121368408203125, -137.02294921875),
]

# Extract latitude and longitude values
latitudes = [coord[0] for coord in global_path]
longitudes = [coord[1] for coord in global_path]
extra_latitudes = [point[0] for point in local_path]
extra_longitudes = [point[1] for point in local_path]

# Create plot
plt.figure(figsize=(10, 6))

# Plot main path
plt.plot(
    longitudes, latitudes, marker="o", linestyle="-", color="b", markersize=5, label="Global Path"
)

# Overlay extra points in red
plt.scatter(extra_longitudes, extra_latitudes, color="red", marker="o", s=50, label="Local Path")

# Indicate first and last points
plt.scatter(
    longitudes[0], latitudes[0], color="green", marker="D", s=100, label="Start (Global Path)"
)
plt.scatter(
    longitudes[-1], latitudes[-1], color="purple", marker="D", s=100, label="End (Global Path)"
)
plt.scatter(
    extra_longitudes[0],
    extra_latitudes[0],
    color="orange",
    marker="s",
    s=100,
    label="Start (Local Path)",
)
plt.scatter(
    extra_longitudes[-1],
    extra_latitudes[-1],
    color="pink",
    marker="s",
    s=100,
    label="End (Local Path)",
)

# Labels and title
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.title("Global and Local Paths")
plt.legend()
plt.grid(True)

# Show the plot
plt.show()
